# %%
import sys
import importlib
sys.path.insert(1, r'C:\Users\alyahyma\Projects\NBA_API\codes')

# Import the module
from my_functions import NBA_functions

# Reload the module (note how we pass the module object directly)
importlib.reload(NBA_functions)

# Now you can use your imported functions
from my_functions.NBA_functions import team_log
from my_functions.NBA_functions import get_team_abbreviation

# %%
# to check available functin 
import my_functions.NBA_functions
from inspect import getmembers, isfunction

functions_list = getmembers(my_functions.NBA_functions, isfunction)
function_names = [name for name, _ in functions_list]
print(function_names)
# Out:
# ['get_team_abbreviation', 'team_log']

# %%
team_log(get_team_abbreviation('lkers'))
# Out:
#        Team_ID     Game_ID     GAME_DATE      MATCHUP WL   W   L  W_PCT  MIN  \
# 0   1610612747  0022400955  MAR 13, 2025    LAL @ MIL  L  40  24  0.625  240
# 1   1610612747  0022400930  MAR 10, 2025    LAL @ BKN  L  40  23  0.635  240
# 2   1610612747  0022400918  MAR 08, 2025    LAL @ BOS  L  40  22  0.645  240
# 3   1610612747  0022400903  MAR 06, 2025  LAL vs. NYK  W  40  21  0.656  265
# 4   1610612747  0022400890  MAR 04, 2025  LAL vs. NOP  W  39  21  0.650  240
# ..         ...         ...           ...          ... ..  ..  ..    ...  ...
# 59  1610612747  0022400118  OCT 30, 2024    LAL @ CLE  L   3   2  0.600  240
# 60  1610612747  0022400111  OCT 28, 2024    LAL @ PHX  L   3   1  0.750  240
# 61  1610612747  0022400096  OCT 26, 2024  LAL vs. SAC  W   3   0  1.000  240
# 62  1610612747  0022400085  OCT 25, 2024  LAL vs. PHX  W   2   0  1.000  240
# 63  1610612747  0022400062  OCT 22, 2024  LAL vs. MIN  W   1   0  1.000  240
#
#     FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0    38  ...   0.833     5    33   38   18    3    4   13  23  106
# 1    37  ...   0.789     8    35   43   31    4    4   15  20  108
# 2    39  ...   0.643     9    36   45   18    6    1   12  17  101
# 3    38  ...   0.821    12    37   49   25    7    4   16  28  113
# 4    48  ...   0.778    17    34   51   32    7    5   14  12  136
# ..  ...  ...     ...   ...   ...  ...  ...  ...  ...  ...  ..  ...
# 59   38  ...   0.848     5    32   37   21    6    0   20   7  110
# 60   39  ...   0.722    11    35   46   25    5    6   11  19  105
# 61   48  ...   0.875    13    32   45   32    8    3   19  19  131
# 62   40  ...   0.744     6    31   37   33   10    5   12  18  123
# 63   42  ...   0.840    15    31   46   22    7    8    7  22  110
#
# [64 rows x 27 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from scipy import stats
from datetime import date
import requests
import matplotlib as mpl

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler

from nba_api.stats.endpoints import leaguegamefinder, teamgamelog, boxscoreadvancedv2
from nba_api.stats.static import teams, players
from nba_api.live.nba.endpoints import scoreboard

import seaborn as sns
